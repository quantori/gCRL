# %%
# ensuring all packages are reloaded each time I run a cell
# %load_ext autoreload
# %autoreload 2

# %%
# importing gcrl
import gcrl

# %% [markdown]
# ## Testing eigengenes

# %%
# running tests
# !pytest -q ../tests/test_eigengenes.py
# Out:
# ..                                                                       [100%]
# 2 passed in 1.76s

# %% [markdown]
# ## Testing partial mcc

# %%
# !pytest -q ../tests/test_partial_mcc.py
# Out:
# ...                                                                      [100%]
# 3 passed in 3.99s

# %% [markdown]
# ## Testing partial mcc permutation

# %%
# !pytest -q ../tests/test_partial_mcc_perm_experiments.py
# Out:
# .                                                                        [100%]
# 1 passed in 5.67s

# %% [markdown]
# ## Testing gCRL-AE training

# %%
# !pytest -q ../tests/test_cli_train_gcrl_ae.py
# Out:
# .                                                                        [100%]
# 1 passed in 2.40s

# %% [markdown]
# ## Testing simulation

# %%
# !pytest -q ../tests/test_grn_sim.py
# Out:
# .                                                                        [100%]
# 1 passed in 0.34s

# %%
# !pytest -q ../tests/test_config.py
# Out:
# ...                                                                      [100%]
# 3 passed in 0.01s

# %%
# !pytest -q ../tests/test_sergio_cli.py
# Out:
# .                                                                        [100%]
# 1 passed in 7.74s

# %% [markdown]
# ## Testing gCRL-VAE training

# %%
# !pytest -q ../tests/test_train_gcrl_vae.py
# Out:
# .                                                                        [100%]
# 1 passed in 2.86s
